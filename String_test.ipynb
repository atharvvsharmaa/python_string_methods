# %%
# 1.by the help of + operator
#2.In + operrator we can add anything example 
string1 = "Hello this"
string2 = "is python class"
print(string1+string2)
# we can use the join() operator where to combine the string example
string3 = "Hi","This","side","Atharv sharma"
print(" ".join(string3))
# Out:
# Hello thisis python class
# Hi This side Atharv sharma

# %%
#3. by the help of index() method
s = "Python"
print(s[0])
# Out:
# P

# %%
#4.
print(len("string1"))
# Out:
# 7

# %%
#5. by the help of .upper()
print(string1.upper())
# Out:
#   HELLO THIS

# %%
#6 by the help of .lower()
print(string1.lower())
# Out:
#   hello this

# %%
#7.replace() method ex
print(string1.replace("Hello","Hey"))
# Out:
#   Hey this

# %%
#8.by the help of .split()
print(string1.split())
# Out:
# ['Hello', 'this']

# %%
#9.by the help of .startswith()
print(string1.startswith("H"))
# Out:
# True

# %%
# 10.by the help of .endswith()
print(string1.endswith("is"))
# Out:
# True

# %%
# 11.by the help of .strip()
string1 = "  Hello this"
print(string1.strip())
# Out:
# Hello this

# %%
# 12 by the help of .index()
print(string1.index("H"))
# Out:
# 2

# %%
# 13. by the help of .count()
print(string2.count("s"))
# Out:
# 3

# %%
# 14 .by the help of .isaipha()
print(string1.isalpha())
# Out:
# False

# %%
# 15. by the help of .isnumer()
print(string1.isnumeric())
# Out:
# False

# %%
#16.
print(string1.isdigit())
# Out:
# False

# %%
#17.
print(string1[::-1])
# Out:
# siht olleH

# %%
#18. by the help of .format
name ="Atharv"
age ="20"
string4 = ("Hello this side {} my age is {}.").format(name,age)
print(string4)
# Out:
# Hello this side Atharv my age is 20.

# %%
#19.
print(string1[1:4])
# Out:
#  He

# %%
#20.
print(string1.replace("Hello","Hey"))
# Out:
#   Hey this
